# %% [markdown]
# # 6 Pandas的函数应用

# %%
import pandas as pd
import numpy as np
# Numpy ufunc 函数，randn跟的是维数
df = pd.DataFrame(np.random.randn(5,4) - 1)
print(df)

print(np.abs(df)) #绝对值
# Out:
#           0         1         2         3
# 0 -1.816379  0.306165 -0.956248 -0.709757
# 1 -1.052860 -2.080832 -0.029744  0.656887
# 2 -1.693719 -2.533577 -1.112952 -1.941721
# 3  0.194592 -1.806568  0.569218 -0.970658
# 4 -2.165948 -0.876986 -1.541789 -0.415038
#           0         1         2         3
# 0  1.816379  0.306165  0.956248  0.709757
# 1  1.052860  2.080832  0.029744  0.656887
# 2  1.693719  2.533577  1.112952  1.941721
# 3  0.194592  1.806568  0.569218  0.970658
# 4  2.165948  0.876986  1.541789  0.415038

# %%
#apply默认作用在列上,x是每一列,因为axis=0
print(df.apply(lambda x : x.max()))
# Out:
# 0    0.465819
# 1    1.918311
# 2   -0.781658
# 3    0.975991
# dtype: float64

# %%
#apply作用在行上
print(df.apply(lambda x : x.max(), axis=1))
# Out:
# 0    0.975991
# 1    0.204757
# 2    1.918311
# 3    0.396872
# 4   -0.347737
# dtype: float64

# %%
# 使用applymap应用到每个数据
print(df.map(lambda x : '%.2f' % x))
df.dtypes
# Out:
#        0      1      2      3
# 0   0.47  -0.32  -1.31   0.98
# 1  -1.52  -0.34  -0.78   0.20
# 2  -0.84   1.92  -1.40  -0.60
# 3  -0.69  -0.61  -1.23   0.40
# 4  -0.35  -2.37  -1.95  -1.22
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
type('%.2f' % 1.3456)
# Out:
# str

# %% [markdown]
# ## 6.4 索引排序（不重要）

# %%
# Series
print(np.random.randint(5, size=5))
print('-'*50)
s4 = pd.Series(range(10, 15), index = np.random.randint(5, size=5)) #索引随机生成
print(s4)
print('-'*50)
# 索引排序,sort_index返回一个新的排好索引的series
print(s4.sort_index())
print(s4)
# s4.loc[0:3]  loc索引值不唯一时直接报错
print(s4.iloc[0:3])
s4[0:3]  #默认用的位置索引
# Out:
# [2 2 0 2 1]
# --------------------------------------------------
# 1    10
# 2    11
# 0    12
# 2    13
# 4    14
# dtype: int64
# --------------------------------------------------
# 0    12
# 1    10
# 2    11
# 2    13
# 4    14
# dtype: int64
# 1    10
# 2    11
# 0    12
# 2    13
# 4    14
# dtype: int64
# 1    10
# 2    11
# 0    12
# dtype: int64
# 1    10
# 2    11
# 0    12
# dtype: int64

# %%
# s4.loc[1:2] #loc索引值唯一时可以切片

# %%
# DataFrame
df4 = pd.DataFrame(np.random.randn(5, 5),
                   index=np.random.randint(5, size=5),
                   columns=np.random.randint(5, size=5))
print(df4)
#轴零是行索引排序
df4_isort = df4.sort_index(axis=0, ascending=False)
print(df4_isort)
# Out:
#           2         3         1         3         0
# 2  0.481626  0.267296 -0.951306 -0.167853 -0.215942
# 0 -0.590575 -0.441858  0.380532  1.001047  1.564096
# 3 -1.641073 -1.698706  0.205363 -0.206155 -0.668905
# 3  0.716457  0.461260  0.742063 -1.594768 -0.449151
# 4  1.401914 -0.229332 -1.285855 -0.761922  0.502977
#           2         3         1         3         0
# 4  1.401914 -0.229332 -1.285855 -0.761922  0.502977
# 3 -1.641073 -1.698706  0.205363 -0.206155 -0.668905
# 3  0.716457  0.461260  0.742063 -1.594768 -0.449151
# 2  0.481626  0.267296 -0.951306 -0.167853 -0.215942
# 0 -0.590575 -0.441858  0.380532  1.001047  1.564096

# %%
#轴1是列索引排序
df4_isort = df4.sort_index(axis=1, ascending=True)
print(df4_isort)
# Out:
#           0         1         2         3         3
# 2 -0.215942 -0.951306  0.481626  0.267296 -0.167853
# 0  1.564096  0.380532 -0.590575 -0.441858  1.001047
# 3 -0.668905  0.205363 -1.641073 -1.698706 -0.206155
# 3 -0.449151  0.742063  0.716457  0.461260 -1.594768
# 4  0.502977 -1.285855  1.401914 -0.229332 -0.761922

# %% [markdown]
# # 6.5 按值排序（机器学习，深度学习不重要，数据分析才需要）

# %%
# 按值排序,by后是column的值
import random
l=[random.randint(0,100) for i in range(24)] #生成24个随机数
df4 = pd.DataFrame(np.array(l).reshape(6,4)) #生成6行4列的dataframe
# print(df4) #查看数据,ndarray
# print('-'*50)
print(df4)
print('-'*50)
#按轴零排序，by后是列名,交换的是行
df4_vsort = df4.sort_values(by=3,axis=0, ascending=False) #寻找的是columns里的3,重要
print(df4_vsort)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import random
#       3 l=[random.randint(0,100) for i in range(24)] #生成24个随机数
# ----> 4 df4 = pd.DataFrame(np.array(l).reshape(6,4)) #生成6行4列的dataframe
#       5 # print(df4) #查看数据,ndarray
#       6 # print('-'*50)
#       7 print(df4)
#
# NameError: name 'pd' is not defined

# %%
#按轴1排序，by后行索引名，交换的是列
df4_vsort = df4.sort_values(by=3,axis=1, ascending=False) #寻找的是index里的3
print(df4_vsort)
# Out:
#     2   0   1    3
# 0  58  65  21   61
# 1  35  88  25   86
# 2  63  65  28    5
# 3  95  64  45   23
# 4  57   0  92  100
# 5  89  52  57   24

# %% [markdown]
# # 6.6 处理缺失数据（重要）

# %%
df_data = pd.DataFrame([np.random.randn(3), [1., 2., np.nan],
                       [np.nan, 4., np.nan], [1., 2., 3.]])
print(df_data.head())
# Out:
#           0         1         2
# 0 -1.264229 -0.514817  1.420473
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data.iloc[2,0]
# Out:
# nan

# %%
#isnull来判断是否有空的数据
print(df_data.isnull())
# Out:
# 0    1
# 1    0
# 2    2
# dtype: int64

# %%
#帮我计算df_data缺失率
print(df_data.isnull().sum()/len(df_data))
# Out:
# 0    0.25
# 1    0.00
# 2    0.50
# dtype: float64

# %% [markdown]
# ## 删除缺失数据

# %%
#默认一个样本，任何一个特征缺失，就删除
#inplace True是修改的是原有的df
#subset=[0]是指按第一列来删除,第一列有空值就删除对应的行
print(df_data.dropna(subset=[0]))
# df_data
# Out:
#           0         1         2
# 0 -1.264229 -0.514817  1.420473
# 1  1.000000  2.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -1.264229 -0.514817  1.420473
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#用的不多，用在某个特征缺失太多时，才会进行删除
print(df_data.dropna(axis=1))  #某列由nan就删除该列
# Out:
#           1
# 0  0.039062
# 1  2.000000
# 2  4.000000
# 3  2.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -1.264229 -0.514817  1.420473
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %% [markdown]
# ## 填充缺失数据

# %%
#均值，中位数，众数填充

# %%
#给零列的空值填为-100，按特征（按列）去填充
print(df_data.iloc[:,0].fillna(-100.))
df_data
# Out:
# 0     -1.264229
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64
#           0         1         2
# 0 -1.264229 -0.514817  1.420473
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#依次拿到每一列
for i in df_data.columns:
    print(df_data.loc[:,i])
# Out:
# 0   -1.264229
# 1    1.000000
# 2         NaN
# 3    1.000000
# Name: 0, dtype: float64
# 0   -0.514817
# 1    2.000000
# 2    4.000000
# 3    2.000000
# Name: 1, dtype: float64
# 0    1.420473
# 1         NaN
# 2         NaN
# 3    3.000000
# Name: 2, dtype: float64

# %%
df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# Out:
# C:\Users\41507\AppData\Local\Temp\ipykernel_10424\3395572301.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_data.iloc[:,0].fillna(-100.,inplace=True)

# %%
df_data.iloc[:,2]=df_data.iloc[:,2].fillna(df_data.iloc[:,2].mean()) #用均值填充空值

# %%
df_data
# Out:
#             0         1         2
# 0   -1.264229 -0.514817  1.420473
# 1    1.000000  2.000000  2.210236
# 2 -100.000000  4.000000  2.210236
# 3    1.000000  2.000000  3.000000
